# %% [markdown]
# # 1.6 awk
#
# This notebook will demonstrate the basics of using `awk` to extract specific fields from within data files.

# %% [markdown]
# #### manual inspection of `artists.txt`
#
# There are at least two options for loading `artists.txt` into your favorite spreadsheet program:
#
# * you already have the file on your computer somewhere on your file system, so you can load it from there (if you can figure it out)
# * you can download the text file from https://raw.githubusercontent.com/SuLab/Applied-Bioinformatics/master/Module-1_bash-jupyter-git/data/art/artists.txt
#
# Note that every row has four columns.

# %% [markdown]
# #### confirm using awk that each row has four columns
# Find and fix the error.
#
# ```
# %%bash
# awk '{print NF}' artists.txt
# ```

# %%
$$bash
cd data/art
awk '{print $NF}' artists.txt
# Out:
#   File "<ipython-input-1-9db92fad5a79>", line 1
#     $$bash
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Print the third column
# Find and fix the error.
# ```
# %%bash
# awk '{print $3}' artists.txt
# ```

# %%
# %%bash
# cd data/art
# awk -F "\t" '{print $3}' artists.txt
# Out:
# Baroque
# Romanticism
# Romanticism
# Romanticism
# Baroque
# Romanticism
# Baroque
# Realism
# Northern Renaissance
# Realism
# Romanticism
# Baroque
# Baroque
# Early Renaissance
# Medieval
# Early Renaissance
# Realism
# Medieval
# Medieval
# Early Renaissance
# High Renaissance
# Early Renaissance
# Baroque
# Baroque
# Baroque
# Rococo
# Neoclassicism
# Impressionism
# Baroque
# Baroque
# Mannerism
# Baroque
# Baroque
# Rococo
# Romanticism
# Baroque
# Baroque
# Rococo
# Baroque
# Baroque
# Mannerism
# Romanticism
# Rococo
# Baroque
# Baroque
# Baroque
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Neoclassicism
# Mannerism
# Baroque
# Baroque
# Baroque
# Baroque
# Mannerism
# Romanticism
# Baroque
# Baroque
# Baroque
# Realism
# Romanticism
# Romanticism
# Romanticism
# Rococo
# Baroque
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Rococo
# Rococo
# Rococo
# Neoclassicism
# Romanticism
# Northern Renaissance
# Romanticism
# Romanticism
# ...

# %% [markdown]
# #### Use `uniq` (and another command) to find the most common art periods
# Find and fix the error(s).
# ```
# %%bash
# awk '{print $3}' artists.txt | uniq
# ```

# %%
# %%bash
# cd data/art
# awk -F "\t" '{print $3}' artists.txt
# Out:
# Baroque
# Romanticism
# Romanticism
# Romanticism
# Baroque
# Romanticism
# Baroque
# Realism
# Northern Renaissance
# Realism
# Romanticism
# Baroque
# Baroque
# Early Renaissance
# Medieval
# Early Renaissance
# Realism
# Medieval
# Medieval
# Early Renaissance
# High Renaissance
# Early Renaissance
# Baroque
# Baroque
# Baroque
# Rococo
# Neoclassicism
# Impressionism
# Baroque
# Baroque
# Mannerism
# Baroque
# Baroque
# Rococo
# Romanticism
# Baroque
# Baroque
# Rococo
# Baroque
# Baroque
# Mannerism
# Romanticism
# Rococo
# Baroque
# Baroque
# Baroque
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Neoclassicism
# Mannerism
# Baroque
# Baroque
# Baroque
# Baroque
# Mannerism
# Romanticism
# Baroque
# Baroque
# Baroque
# Realism
# Romanticism
# Romanticism
# Romanticism
# Rococo
# Baroque
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Rococo
# Rococo
# Rococo
# Neoclassicism
# Romanticism
# Northern Renaissance
# Romanticism
# Romanticism
# ...

# %%
# %%bash
# cd data/art
# awk -F "\t" '{print $3}' artists.txt | sort -u
# Out:
# Baroque
# Early Renaissance
# High Renaissance
# Impressionism
# Mannerism
# Medieval
# Neoclassicism
# Northern Renaissance
# Realism
# Rococo
# Romanticism

# %%
# %%bash
# cd data/art
# sort artists.txt | uniq -u
# Out:
# AACHEN, Hans von	(1552-1615)	Mannerism	German painter
# AAGAARD, Carl Frederik	(1833-1895)	Realism	Danish painter (Copenhagen)
# ABADIA, Juan de la	(active 1470-1490)	Early Renaissance	Spanish painter (Huesca)
# ABAQUESNE, Masséot	(c 1500-1564)	High Renaissance	French potter
# ABBATE, Niccolò dell'	(1509-1571)	Mannerism	Italian painter (Bologna)
# ABBATI, Giuseppe	(1836-1868)	Realism	Italian painter
# ABBATINI, Guido Ubaldo	(c. 1602-1656)	Baroque	Italian painter (Rome)
# ABBONDI, Antonio di Pietro (see SCARPAGNINO)	(c. 1465-1549)	High Renaissance	Italian architect (Venice)
# ABEELE, Pieter van	(1608-1684)	Baroque	Dutch sculptor (Amsterdam)
# ABILDGAARD, Nicolai	(1743-1809)	Romanticism	Danish painter
# ABONDIO, Antonio	(1538-1591)	Mannerism	Italian sculptor (Vienna)
# ACERO Y AREBO, Vicente	(c. 1677-1739)	Baroque	Spanish architect
# ACHENBACH, Oswald	(1827-1905)	Realism	German painter (Dusseldorf)
# ADAM, Albrecht	(1786-1862)	Romanticism	German painter (Munich)
# ...

# %% [markdown]
# ## Homework

# %% [markdown]
# ### HW1: Repeat the above command (finding the most common art periods) restricting to Dutch painters only.
# HINT: start by searching/filtering for Dutch painters...

# %%
# %%bash
# cd data/art
# grep "Dutch" artists.txt
# Out:
# TEMPEL, Abraham van den	(1622/23-1672)	Baroque	Dutch painter (Amsterdam)
# TEMPESTA, Pietro (see MULIER, Pieter the Younger)	(1637-1701)	Baroque	Dutch painter (Italy)
# TENGNAGEL, Jan	(1584-1635)	Baroque	Dutch painter (Amsterdam)
# TERBORCH, Gerard	(1617-1681)	Baroque	Dutch painter (Deventer)
# TERBRUGGHEN, Hendrick	(1588-1629)	Baroque	Dutch painter (Utrecht)
# KNIJFF, Jacob	(1639-1681)	Baroque	Dutch painter (London)
# KNIJFF, Wouter	(c. 1607-after 1693)	Baroque	Dutch painter (Haarlem)
# KNIP, Henriëtte	(1821-1909)	Realism	Dutch painter (Brussels)
# KNIP, Henriëtte Geertruida	(1783-1842)	Romanticism	Dutch painter
# KNIP, Josephus Augustus	(1777-1847)	Romanticism	Dutch painter
# KNIP, Mattheus Derk	(1785-1845)	Romanticism	Dutch painter
# KNIP, Nicolaas Frederik	(1741-1808)	Rococo	Dutch painter
# KNÜPFER, Nicolaus	(c. 1603-1655)	Baroque	Dutch painter
# KNYFF, Jacob (see KNIJFF, Jacob)	(1639-1681)	Baroque	Dutch painter (London)
# ...

# %%
# %%bash
# cd data/art
# awk -F "\t" '{print $3}' artists.txt | grep "Dutch" artists.txt | uniq -u
# Out:
# TEMPEL, Abraham van den	(1622/23-1672)	Baroque	Dutch painter (Amsterdam)
# TEMPESTA, Pietro (see MULIER, Pieter the Younger)	(1637-1701)	Baroque	Dutch painter (Italy)
# TENGNAGEL, Jan	(1584-1635)	Baroque	Dutch painter (Amsterdam)
# TERBORCH, Gerard	(1617-1681)	Baroque	Dutch painter (Deventer)
# TERBRUGGHEN, Hendrick	(1588-1629)	Baroque	Dutch painter (Utrecht)
# KNIJFF, Jacob	(1639-1681)	Baroque	Dutch painter (London)
# KNIJFF, Wouter	(c. 1607-after 1693)	Baroque	Dutch painter (Haarlem)
# KNIP, Henriëtte	(1821-1909)	Realism	Dutch painter (Brussels)
# KNIP, Henriëtte Geertruida	(1783-1842)	Romanticism	Dutch painter
# KNIP, Josephus Augustus	(1777-1847)	Romanticism	Dutch painter
# KNIP, Mattheus Derk	(1785-1845)	Romanticism	Dutch painter
# KNIP, Nicolaas Frederik	(1741-1808)	Rococo	Dutch painter
# KNÜPFER, Nicolaus	(c. 1603-1655)	Baroque	Dutch painter
# KNYFF, Jacob (see KNIJFF, Jacob)	(1639-1681)	Baroque	Dutch painter (London)
# ...

# %% [markdown]
# ### HW2: Find the most common last names among all artists in `artists.txt`.
# HINT: you will use `awk`, `sort`, and `uniq`, and you may use one or more of those commands multiple times

# %%
# %%bash
# cd data/art
# sort artists.txt | uniq -ic
# Out:
#    1 AACHEN, Hans von	(1552-1615)	Mannerism	German painter
#    1 AAGAARD, Carl Frederik	(1833-1895)	Realism	Danish painter (Copenhagen)
#    1 ABADIA, Juan de la	(active 1470-1490)	Early Renaissance	Spanish painter (Huesca)
#    1 ABAQUESNE, Masséot	(c 1500-1564)	High Renaissance	French potter
#    1 ABBATE, Niccolò dell'	(1509-1571)	Mannerism	Italian painter (Bologna)
#    1 ABBATI, Giuseppe	(1836-1868)	Realism	Italian painter
#    1 ABBATINI, Guido Ubaldo	(c. 1602-1656)	Baroque	Italian painter (Rome)
#    1 ABBONDI, Antonio di Pietro (see SCARPAGNINO)	(c. 1465-1549)	High Renaissance	Italian architect (Venice)
#    1 ABEELE, Pieter van	(1608-1684)	Baroque	Dutch sculptor (Amsterdam)
#    1 ABILDGAARD, Nicolai	(1743-1809)	Romanticism	Danish painter
#    1 ABONDIO, Antonio	(1538-1591)	Mannerism	Italian sculptor (Vienna)
#    1 ACERO Y AREBO, Vicente	(c. 1677-1739)	Baroque	Spanish architect
#    1 ACHENBACH, Oswald	(1827-1905)	Realism	German painter (Dusseldorf)
# ...

# %%
# %%bash
# cd data/art
# awk -F "\t" '{print $1}' artists.txt | sort -u artists.txt
# Out:
# AACHEN, Hans von	(1552-1615)	Mannerism	German painter
# AAGAARD, Carl Frederik	(1833-1895)	Realism	Danish painter (Copenhagen)
# ABADIA, Juan de la	(active 1470-1490)	Early Renaissance	Spanish painter (Huesca)
# ABAQUESNE, Masséot	(c 1500-1564)	High Renaissance	French potter
# ABBATE, Niccolò dell'	(1509-1571)	Mannerism	Italian painter (Bologna)
# ABBATI, Giuseppe	(1836-1868)	Realism	Italian painter
# ABBATINI, Guido Ubaldo	(c. 1602-1656)	Baroque	Italian painter (Rome)
# ABBONDI, Antonio di Pietro (see SCARPAGNINO)	(c. 1465-1549)	High Renaissance	Italian architect (Venice)
# ABEELE, Pieter van	(1608-1684)	Baroque	Dutch sculptor (Amsterdam)
# ABILDGAARD, Nicolai	(1743-1809)	Romanticism	Danish painter
# ABONDIO, Antonio	(1538-1591)	Mannerism	Italian sculptor (Vienna)
# ACERO Y AREBO, Vicente	(c. 1677-1739)	Baroque	Spanish architect
# ACHENBACH, Oswald	(1827-1905)	Realism	German painter (Dusseldorf)
# ADAM, Albrecht	(1786-1862)	Romanticism	German painter (Munich)
# ...

# %%
# %%bash
# cd data/art
# awk -F "\t" '{print $1}' artists.txt | uniq -c
# Out:
# KILIAN, Wolfgang
# KINSOEN, François-Joseph
# KISS, August Karl Edouard
# KISS, Bálint
# KLEINER, Salomon
# KLENZE, Leo von
# KLESECKER, Justus (see GLESKER, Justus)
# KLINGER, Max
# KLOCKER, Hans
# KLODT, Mikhail Konstantinovich
# KLODT, Pyotr Karlovich
# TACCA, Ferdinando
# TACCA, Pietro
# TACCONE, Paolo (see PAOLO ROMANO)
# TADDEO DI BARTOLO
# TADDEO DI FERRARA (see CRIVELLI, Taddeo)
# TADOLINI, Scipione
# TALENTI, Francesco
# TALENTI, Simone
# TALPA, Bartolo
# TAMAGNI, Vincenzo
# TAMAGNINO, Antonio (see PORTA, Antonio della)
# TAMM, Franz Werner von
# TANZIO DA VARALLO
# TARAVAL, Guillaume-Thomas-Raphaël
# TARAVAL, Hugues
# TARAVAL, Louis-Gustave
# TARBELL, Edmund Charles
# TARCHIANI, Filippo
# TARDIEU, Nicolas-Henry
# TARGONE, Cesare
# TARSIA, Antonio
# TARUFFI, Emilio
# TASSAERT, Jean-Pierre-Antoine
# TASSAERT, Octave
# TASSEL, Jean
# TASSI, Agostino
# TAUNAY, Nicolas Antoine
# TEDESCO, Carlo (see SFERINI, Carlo Leopoldo)
# TEDESCO, Giovanni Paolo (see SCHOR, Johann Paul)
# ...
